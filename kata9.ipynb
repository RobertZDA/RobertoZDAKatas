# %%
def funcion(tanque1, tanque2, tanque3):
    
    total_average = (tanque1 + tanque2 + tanque3) / 3
    
    return f"""Fuel Report:
    Total Average: {round(total_average)}%
    Primer tanque: {tanque1}%
    Segundo tanque: {tanque2}%
    Tercer tanque: {tanque3}% 
    """

print(funcion(20, 45, 60))
# Out:
# Fuel Report:
#     Total Average: 42%$
#     Main tank: 20%$
#     External tank: 45%$
#     Hydrogen tank: 60% $

# %% [markdown]
# # Segundo problema

# %%
def reporte(prelanzamiento, vuelo, lugar, tanque_externo, tanque_interno):

    return f"""

    Bienvenido tripulante
    El planeta el cual se visitará es {lugar}
    Tiempo total: {prelanzamiento + vuelo} minutos
    {tanque_externo + tanque_interno} litros es lo que nos queda de gasolina

    """

print(reporte(14, 51, 'Marte', 30, 40))


def reporte(prelanzamiento, vuelo, lugar, tanque_externo, tanque_interno):

    return f"""

    Bienvenido tripulante
    El planeta el cual se visitará es {lugar}
    Tiempo total: {prelanzamiento + vuelo} minutos
    {tanque_externo} litros es lo que nos queda en el tanque externo
    y por ultimo {tanque_interno} litros es lo que nos queda en el tanque interno

    """

print(reporte(14, 51, 'Marte', 30, 40))
# Out:
#     Bienvenido tripulante
#     El planeta el cual se visitará es Marte
#     Tiempo total: 65 minutos
#     70 litros es lo que nos queda de gasolina
#
#
#
#
#     Bienvenido tripulante
#     El planeta el cual se visitará es Marte
#     Tiempo total: 65 minutos
#     30 litros es lo que nos queda en el tanque externo
#     y por ultimo 40 litros es lo que nos queda en el tanque interno
