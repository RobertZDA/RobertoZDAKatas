# %% [markdown]
# # Primer problema

# %%
asteroide = 49

if asteroide > 25 :

    print("¡Advertencia! Un asteroide con velocidad de " + str(asteroide) + " km/s se acerca a la tierra")

else:
    
    print("Todo en orden :)")
# Out:
# ¡Advertencia! Un asteroide con velocidad de 49 km/s se acerca a la tierra

# %% [markdown]
# # Segundo problema

# %%
asteroide = 19

if asteroide >= 20 :

    print("¡Se puede ver el rayo de luz ahora mismo!")

else:

    print("No se puede ver nada :(")
# Out:
# No se puede ver nada :(

# %% [markdown]
# # Tercer problema

# %%
tamaño = 60
velocidad = 30


if tamaño > 25 and velocidad < 1000 :
    
    print("¡Mucho cuidado se acerca un asteroide con tamaño de " + str(asteroide) + " metros!")

elif velocidad >=20:
    print("Se puede ver el rayo de luz en el cielo :O")
# Out:
# ¡Mucho cuidado se acerca un asteroide con tamaño de 60 metros!
