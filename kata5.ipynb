# %% [markdown]
# # Primer problema

# %%
tierra = 149597870
jupiter = 778547200

distancia = (jupiter - tierra) 

millas = distancia * 0.621

print(distancia)
print (round(millas))
# Out:
# 628949330
# 390577534

# %% [markdown]
# # Segundo problema

# %%
planeta1 = input("Ingresa una distancia del sol :D")
planeta2 = input("¡Ahora ingresa la distancia de otro planeta!")

planeta1= int(planeta1)
planeta2= int(planeta2)

distancia = planeta2 - planeta1
print(f"""{distancia} es la distancia :O""")

millas = distancia * 0.621
print("Esta es la distancia en millas: " , abs(millas))
# Out:
# 900 es la distancia :O
# Esta es la distancia en millas:  558.9
